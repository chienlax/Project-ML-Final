# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 500)

# %%
data = pd.read_csv('C:\\Users\\ORLab\\main_source\\Project-ML-Final\\output\\2024_1\\2024_1_HN.csv', encoding='utf-8-sig')

# %%
data.groupby(by=['Mã HP','Tên HP']).agg({'Time slot':'unique'}).sort_index()
# Out:
#                                                 Time slot
# Mã HP      Tên HP
# TXBHKT01   Quản trị kinh doanh bảo hiểm              [22]
# TXBHKT1118 Nguyên lý bảo hiểm                        [21]
# TXDTKT1170 Thẩm định dự án đầu tư                    [19]
# TXKHEH1105 Lịch sử kinh tế                           [21]
# TXKHMA01   Kinh tế vĩ mô 1                            [3]
# TXKHMI01   Kinh tế vi mô 1                           [23]
# TXKTHT1105 Kiểm soát nội bộ                          [19]
# TXKTKE01   Nguyên lý kế toán                          [6]
# TXKTKE02   Kế toán công                              [22]
# TXKTKE1108 Kế toán quốc tế                           [22]
# TXKTKE1109 Kế toán công 1                            [20]
# TXKTKI02   Kiểm toán tài chính 1                     [23]
# TXKTKI03   Kiểm toán căn bản                         [21]
# TXKTQT01   Kế toán quản trị 1                         [9]
# TXKTQT03   Hệ thống thông tin kế toán                [17]
# ...

# %%
data.groupby(by=['Time slot']).agg({'Tên HP':'nunique'}).sort_index()
# Out:
#            Tên HP
# Time slot
# 0               5
# 1               3
# 2               4
# 3               4
# 4               5
# 5               5
# 6               5
# 7               6
# 8               5
# 9               7
# 10              4
# 11              5
# 12              5
# 13              7
# 14              7
# 15              8
# 16              4
# 17              7
# 18              5
# 19              7
# 20              7
# 21              8
# 22              6
# 23              4
