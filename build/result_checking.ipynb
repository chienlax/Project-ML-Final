# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 500)

# %%
data = pd.read_csv('C:\\Users\\ORLab\\main_source\\Project-ML-Final\\output\\2024_1\\2024_1_HN.csv', encoding='utf-8-sig')

# %%
data.groupby(by=['Mã HP','Tên HP']).agg({'Time slot':'unique', 'Mã SV':'count'}).sort_index()
# Out:
#                                                 Time slot  Mã SV
# Mã HP      Tên HP
# TXBHKT01   Quản trị kinh doanh bảo hiểm              [23]     10
# TXBHKT1118 Nguyên lý bảo hiểm                        [22]     35
# TXDTKT1170 Thẩm định dự án đầu tư                    [21]     74
# TXKHEH1105 Lịch sử kinh tế                           [23]     19
# TXKHMA01   Kinh tế vĩ mô 1                            [2]    194
# TXKHMI01   Kinh tế vi mô 1                            [6]     48
# TXKTHT1105 Kiểm soát nội bộ                          [20]     17
# TXKTKE01   Nguyên lý kế toán                         [21]    209
# TXKTKE02   Kế toán công                              [23]     10
# TXKTKE1108 Kế toán quốc tế                            [6]    107
# TXKTKE1109 Kế toán công 1                            [18]     17
# TXKTKI02   Kiểm toán tài chính 1                     [22]     30
# TXKTKI03   Kiểm toán căn bản                         [16]     33
# ...

# %%
data.groupby(by=['Time slot', 'Tên HP']).agg({'Mã SV':'count'}).sort_index()
# Out:
#                                                 Mã SV
# Time slot Tên HP
# 0         Giao tiếp kinh doanh                    228
#           Kinh doanh quốc tế 1                     11
#           Kinh tế quốc tế                         153
#           Ngân hàng thương mại 2                   28
#           Pháp luật an sinh xã hội                 33
#           Phân tích kinh doanh                    145
#           Tài chính công 2                         31
# 1         Chuyên đề marketing ngân hàng            11
#           Công pháp quốc tế                       103
#           Kế toán quản trị 1                       23
#           Ngân hàng phát triển                      7
#           Quản trị chiến lược                     136
#           Quản trị chất lượng                     120
#           Thị trường chứng khoán 1                 81
#           Toán cho các nhà kinh tế                192
# 2         Kinh tế vĩ mô 1                         194
# ...
